# %% [markdown]
# <a href="https://colab.research.google.com/github/prathiksha061/Day1/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Varriables

# %%
name = "Suvalakshmi Prathiksha P"
print (name)
# Out:
# Suvalakshmi Prathiksha P

# %%
a =10
b=20
a, b = b, a
print (a,b)
# Out:
# 20 10

# %%
x,y,z = 1,2,3
sum = x+y+z
print(sum)
# Out:
# 6

# %%
x= 100
print("before", x)
x= 200
print("After", x)
# Out:
# before 100
# After 200

# %%
x= 50
print(x)
del x
print(x)
# Out:
# 50
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10646/4063253380.py in <cell line: 0>()
#       2 print(x)
#       3 del x
# ----> 4 print(x)
#
# NameError: name 'x' is not defined

# %% [markdown]
# Data Types

# %%
a= 10
b= .5
c= "data"
d= True
print(a,type(a),b,type(b),c,type(c),d,type(d))
# Out:
# 10 <class 'int'> 0.5 <class 'float'> data <class 'str'> True <class 'bool'>

# %%
x= 3.14
y= "Hello"
z= True
w= 0
print(type(x),type(y),type(z),type(w))
# Out:
# <class 'float'> <class 'str'> <class 'bool'> <class 'int'>

# %%
x= 9
print(isinstance(x, int))
# Out:
# True

# %%
x = None
print(type(x))
# Out:
# <class 'NoneType'>

# %%
a= 99999999999999999999999999999999999999999
b= .0000000000000000000000000000000000009
print(a,b)
# Out:
# 99999999999999999999999999999999999999999 9e-37

# %% [markdown]
# Type Conversion

# %%
a="123"
a= int(a)
a=a+7
print(a)
# Out:
# 130

# %%
a=9.99
a=int(a)
print(a)
# Out:
# 9

# %%
a,b=0,1
a=bool(a)
b=bool(b)
print(a,b)
# Out:
# False True

# %%
a,b= True ,False
a, b= int(a),int(b)
print(a,b)
# Out:
# 1 0

# %%
x= input("Enter a number: ")
x=float(x)
x=x*2
print(x)
# Out:
# Enter a number: 5.1
# 10.2

# %%
x= "hello"
x=int(x)
print(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10646/1777535510.py in <cell line: 0>()
#       1 x= "hello"
# ----> 2 x=int(x)
#       3 print(x)
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %% [markdown]
# String Manipulation

# %%
x= "Hello World"
print(x.upper())
print(x.lower())
# Out:
# HELLO WORLD
# hello world

# %%
x= "Python Programming"
print(len(x))
# Out:
# 18

# %%
x= "Hello, World!"
print(x[7:12])
# Out:
# World

# %%
x="abcdef"
print(x[::-1])
# Out:
# fedcba

# %%
x= "banana"
if "nan" in x:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
x= "This is a bad day"

print(x.replace("bad", "good"))
# Out:
# This is a good day

# %%
x = " hello "

print(x.strip())
# Out:
# hello

# %%
x = "apple,banana,cherry"
print(x.split(","))
# Out:
# ['apple', 'banana', 'cherry']

# %%
x = "banana"
print(x.count("a"))
# Out:
# 3

# %%
x= "Python123"
print(x.isalnum())
# Out:
# True

# %% [markdown]
# String formatting

# %%
x = "John"
y = 25
print(f"My name is {x} and I am {y} years old")
# Out:
# My name is John and I am 25 years old

# %%
x = 49.99
print("The price is {} dollars".format(x))
# Out:
# The price is 49.99 dollars

# %%
x = 3.14159
print(f"{x:.2f}")
# Out:
# 3.14

# %%
x= 7
print(f"{x:03}")
# Out:
# 007

# %%
x= 5
y = 3
print(f"{x} x {y} = {x*y}")
# Out:
# 5 x 3 = 15

# %%
names = ["John", "Anna", "Mike"]
scores = [85, 92, 78]

for i in range(3):
    print(names[i], scores[i])
# Out:
# John 85
# Anna 92
# Mike 78

# %% [markdown]
# Lists

# %%
x= ["apple", "banana", "cherry", "orange", "grape"]
print(x)
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'grape']

# %%
l = [10, 20, 30, 40, 50]
print(l[0])
print(l[-1])
# Out:
# 10
# 50

# %%
l = [1, 2, 3]
l.append(4)
print(l)
# Out:
# [1, 2, 3, 4]

# %%
l= [10, 20, 30, 40]
l.insert(2, 99)
print(l)
# Out:
# [10, 20, 99, 30, 40]

# %%
x= ["apple", "banana", "cherry", "orange", "grape"]
x.remove("banana")
print(x)
# Out:
# ['apple', 'cherry', 'orange', 'grape']

# %%
l= [5, 2, 8, 1, 9]
l.sort()
print(l)

l=l[::-1]
print(l)
# Out:
# [1, 2, 5, 8, 9]
# [9, 8, 5, 2, 1]

# %%
l = [3, 7, 1, 9, 4]
print(len(l))
print(max(l))
print(min(l))
# Out:
# 5
# 9
# 1

# %%
l= [0, 1, 2, 3, 4, 5, 6]
print(l[2:5])
# Out:
# [2, 3, 4]

# %%
l= [1, 2, 3]
l1= l.copy()
l1.append(4)
print(l,l1)
# Out:
# [1, 2, 3] [1, 2, 3, 4]

# %%
a = [1, 2, 3]
b = [4, 5, 6]

c = a + b

print(c)
# Out:
# [1, 2, 3, 4, 5, 6]
